# %% [markdown]
# # 1. Business Problem Statement
#
#  Our company is entering the film production industry without prior experience.
#  We aim to analyze existing movie data to discover which types of movies succeed at the box office.
#
# ## Objective:
# Make data-driven decisions to launch a profitable movie studio.

# %% [markdown]
# # 2. Business Solution
#  Analyze multiple movie datasets to:
# - Discover profitable genres.
# - Determine ideal production budgets.
# - Identify the best release dates.
# - Analyze the relationship between budgets and profits.
# - Generate actionable recommendations.

# %% [markdown]
# # 3. Business Objectives
# - Identify top-performing genres.
# - Find ideal production budget ranges for maximum ROI.
# - Recommend best movie release months.
# - Test the relationship between production budget and profits.
# - Suggest optimal movie runtime.
# - Deliver clear business strategies.

# %% [markdown]
# # 4. Data Overview
# We will use the following datasets:
# - bom.movie_gross.csv.gz
# - rt.movie_info.tsv.gz
# - rt.reviews.tsv.gz
# - tmdb.movies.csv.gz
# - tn.movie_budgets.csv.gz

# %% [markdown]
# # 5. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlite3
from scipy import stats
import statsmodels.api as sm

sns.set(style="whitegrid")

# %% [markdown]
# # 6. Load Datasets
# We will load the first five datasets

# %%
df = pd.read_csv('bom.movie_gross.csv.gz')
df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
df.columns
# Out:
# Index(['title', 'studio', 'domestic_gross', 'foreign_gross', 'year'], dtype='object')

# %%
df1 = pd.read_csv('rt.movie_info.tsv.gz', sep='\t')
df1
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# 0                   Action and Adventure|Classics|Drama    William Friedkin
# 1                     Drama|Science Fiction and Fantasy    David Cronenberg
# 2                     Drama|Musical and Performing Arts      Allison Anders
# 3                            Drama|Mystery and Suspense      Barry Levinson
# 4                                         Drama|Romance      Rodney Bennett
# ...                                                 ...                 ...
# 1555   Action and Adventure|Horror|Mystery and Suspense                 NaN
# 1556                 Comedy|Science Fiction and Fantasy        Steve Barron
# 1557  Classics|Comedy|Drama|Musical and Performing Arts      Gordon Douglas
# 1558    Comedy|Drama|Kids and Family|Sports and Fitness  David Mickey Evans
# 1559  Action and Adventure|Art House and Internation...                 NaN
#
#                                                 writer  theater_date  \
# 0                                       Ernest Tidyman   Oct 9, 1971
# 1                         David Cronenberg|Don DeLillo  Aug 17, 2012
# 2                                       Allison Anders  Sep 13, 1996
# 3                      Paul Attanasio|Michael Crichton   Dec 9, 1994
# 4                                         Giles Cooper           NaN
# ...                                                ...           ...
# 1555                                               NaN  Aug 18, 2006
# 1556  Terry Turner|Tom Davis|Dan Aykroyd|Bonnie Turner  Jul 23, 1993
# 1557                                               NaN   Jan 1, 1962
# 1558                  David Mickey Evans|Robert Gunter   Apr 1, 1993
# 1559                                        Luc Besson  Sep 27, 2001
#
#           dvd_date currency  box_office      runtime             studio
# 0     Sep 25, 2001      NaN         NaN  104 minutes                NaN
# 1      Jan 1, 2013        $     600,000  108 minutes  Entertainment One
# 2     Apr 18, 2000      NaN         NaN  116 minutes                NaN
# 3     Aug 27, 1997      NaN         NaN  128 minutes                NaN
# 4              NaN      NaN         NaN  200 minutes                NaN
# ...            ...      ...         ...          ...                ...
# 1555   Jan 2, 2007        $  33,886,034  106 minutes    New Line Cinema
# 1556  Apr 17, 2001      NaN         NaN   88 minutes  Paramount Vantage
# 1557  May 11, 2004      NaN         NaN  111 minutes                NaN
# 1558  Jan 29, 2002      NaN         NaN  101 minutes                NaN
# 1559  Feb 11, 2003      NaN         NaN   94 minutes  Columbia Pictures
#
# [1560 rows x 12 columns]

# %%
df1.columns
# Out:
# Index(['id', 'synopsis', 'rating', 'genre', 'director', 'writer',
#        'theater_date', 'dvd_date', 'currency', 'box_office', 'runtime',
#        'studio'],
#       dtype='object')

# %%
df2 = pd.read_csv('rt.reviews.tsv.gz', sep='\t', encoding='latin_1')
df2
# Out:
#          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1         3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2         3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3         3  Continuing along a line introduced in last yea...    NaN   fresh
# 4         3             ... a perverse twist on neorealism...     NaN   fresh
# ...     ...                                                ...    ...     ...
# 54427  2000  The real charm of this trifle is the deadpan c...    NaN   fresh
# 54428  2000                                                NaN    1/5  rotten
# 54429  2000                                                NaN    2/5  rotten
# 54430  2000                                                NaN  2.5/5  rotten
# 54431  2000                                                NaN    3/5   fresh
#
#                   critic  top_critic         publisher                date
# 0             PJ Nabarro           0   Patrick Nabarro   November 10, 2018
# 1         Annalee Newitz           0           io9.com        May 23, 2018
# 2           Sean Axmaker           0  Stream on Demand     January 4, 2018
# 3          Daniel Kasman           0              MUBI   November 16, 2017
# 4                    NaN           0      Cinema Scope    October 12, 2017
# ...                  ...         ...               ...                 ...
# 54427      Laura Sinagra           1     Village Voice  September 24, 2002
# 54428  Michael Szymanski           0        Zap2it.com  September 21, 2005
# 54429       Emanuel Levy           0   EmanuelLevy.Com       July 17, 2005
# 54430   Christopher Null           0    Filmcritic.com   September 7, 2003
# 54431    Nicolas Lacroix           0      Showbizz.net   November 12, 2002
#
# [54432 rows x 8 columns]

# %%
df2.columns
# Out:
# Index(['id', 'review', 'rating', 'fresh', 'critic', 'top_critic', 'publisher',
#        'date'],
#       dtype='object')

# %%
df3 = pd.read_csv('tmdb.movies.csv.gz')
df3.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
df3.columns
# Out:
# Index(['Unnamed: 0', 'genre_ids', 'id', 'original_language', 'original_title',
#        'popularity', 'release_date', 'title', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
df4 = pd.read_csv('tn.movie_budgets.csv.gz')
df4
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# 1         $410,600,000   $241,063,875  $1,045,663,875
# 2         $350,000,000    $42,762,350    $149,762,350
# 3         $330,600,000   $459,005,868  $1,403,013,963
# 4         $317,000,000   $620,181,382  $1,316,721,747
# ...                ...            ...             ...
# 5777            $7,000             $0              $0
# 5778            $6,000        $48,482        $240,495
# 5779            $5,000         $1,338          $1,338
# 5780            $1,400             $0              $0
# 5781            $1,100       $181,041        $181,041
#
# [5782 rows x 6 columns]

# %%
df4.columns
# Out:
# Index(['id', 'release_date', 'movie', 'production_budget', 'domestic_gross',
#        'worldwide_gross'],
#       dtype='object')

# %% [markdown]
# # 7. Data Cleaning

# %%
print("Before cleaning:")
print(df.shape, df1.shape, df2.shape, df3.shape, df4.shape)
# Out:
# Before cleaning:
# (3387, 5) (1560, 12) (54432, 8) (26517, 10) (5782, 6)

# %% [markdown]
# ### Removing duplicates
# Lets remove all duplicate rows in the dataframes

# %%
df.drop_duplicates(inplace=True)
df1.drop_duplicates(inplace=True)
df2.drop_duplicates(inplace=True)
df3.drop_duplicates(inplace=True)
df4.drop_duplicates(inplace=True)

# %% [markdown]
# ### Fix money columns
# Lets remove all duplicate rows in the dataframes

# %%
df['domestic_gross'] = pd.to_numeric(df['domestic_gross'], errors='coerce')
df['foreign_gross'] = pd.to_numeric(df['foreign_gross'], errors='coerce')
df4['production_budget'] = df4['production_budget'].replace('[\\$,]', '', regex=True).astype(float)
df4['domestic_gross'] = df4['domestic_gross'].replace('[\\$,]', '', regex=True).astype(float)
df4['worldwide_gross'] = df4['worldwide_gross'].replace('[\\$,]', '', regex=True).astype(float)

# %% [markdown]
# ### Fix Date Columns

# %%
df1['theater_date'] = pd.to_datetime(df1['theater_date'], errors='coerce')
df1['dvd_date'] = pd.to_datetime(df1['dvd_date'], errors='coerce')
df4['release_date'] = pd.to_datetime(df4['release_date'], errors='coerce')

# %%
print("After cleaning:")
print(df.shape, df1.shape, df2.shape, df3.shape, df4.shape)
# Out:
# After cleaning:
# (3387, 5) (1560, 12) (54423, 8) (26517, 10) (5782, 6)

# %% [markdown]
# ### fix title columns

# %%
import pandas as pd
import re

def clean_title(title):
    if pd.isnull(title):
        return ""
    title = title.lower()  # lowercase
    title = title.strip()  # remove leading/trailing spaces
    title = re.sub(r'\s+', ' ', title)  # normalize multiple spaces
    title = re.sub(r'[^a-z0-9 ]', '', title)  # remove punctuation and special chars
    return title

# %%
df['clean_title'] = df['title'].apply(clean_title)
df4['clean_title'] = df4['movie'].apply(clean_title)
df3['clean_title'] = df3['title'].apply(clean_title)

# %% [markdown]
# # 8. Merge Datasets

# %%
df_merged = df.merge(df3, on='clean_title', how="inner")
df_merged
# Out:
#                                           title_x  studio  domestic_gross  \
# 0                                     Toy Story 3      BV     415000000.0
# 1     Harry Potter and the Deathly Hallows Part 1      WB     296000000.0
# 2                                       Inception      WB     292600000.0
# 3                             Shrek Forever After    P/DW     238700000.0
# 4                      The Twilight Saga: Eclipse    Sum.     300500000.0
# ...                                           ...     ...             ...
# 2842                                   The Escape     IFC         14000.0
# 2843                                   The Escape     IFC         14000.0
# 2844                                     Souvenir  Strand         11400.0
# 2845                                    The Quake   Magn.          6200.0
# 2846                            An Actor Prepares   Grav.          1700.0
#
#       foreign_gross  year                                  clean_title  \
# 0       652000000.0  2010                                  toy story 3
# 1       664300000.0  2010  harry potter and the deathly hallows part 1
# 2       535700000.0  2010                                    inception
# 3       513900000.0  2010                          shrek forever after
# 4       398000000.0  2010                    the twilight saga eclipse
# ...             ...   ...                                          ...
# 2842            NaN  2018                                   the escape
# 2843            NaN  2018                                   the escape
# 2844            NaN  2018                                     souvenir
# 2845            NaN  2018                                    the quake
# 2846            NaN  2018                            an actor prepares
#
#       Unnamed: 0                genre_ids      id original_language  \
# 0              7          [16, 10751, 35]   10193                en
# 1              0          [12, 14, 10751]   12444                en
# 2              4            [28, 878, 12]   27205                en
# 3             38  [35, 12, 14, 16, 10751]   10192                en
# 4             15      [12, 14, 18, 10749]   24021                en
# ...          ...                      ...     ...               ...
# 2842       16803                 [53, 28]  459814                en
# 2843       19053                 [53, 28]  417004                en
# 2844       18483                 [35, 18]  408258                fr
# 2845       24107                     [12]  416194                no
# 2846       24419                 [35, 18]  434596                en
#
#                                     original_title  popularity release_date  \
# 0                                      Toy Story 3      24.445   2010-06-17
# 1     Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 2                                        Inception      27.920   2010-07-16
# 3                              Shrek Forever After      15.041   2010-05-16
# 4                       The Twilight Saga: Eclipse      20.340   2010-06-23
# ...                                            ...         ...          ...
# 2842                                    The Escape       0.600   2015-08-14
# 2843                                    The Escape       1.176   2016-10-23
# 2844                                      Souvenir       2.130   2016-09-08
# 2845                                      Skjelvet      11.051   2018-12-14
# 2846                             An Actor Prepares       7.244   2018-08-31
#
#                                            title_y  vote_average  vote_count
# 0                                      Toy Story 3           7.7        8340
# 1     Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 2                                        Inception           8.3       22186
# 3                              Shrek Forever After           6.1        3843
# 4                       The Twilight Saga: Eclipse           6.0        4909
# ...                                            ...           ...         ...
# 2842                                    The Escape           7.0           1
# 2843                                    The Escape           6.6          10
# 2844                                      Souvenir           5.8          14
# 2845                                     The Quake           6.7          81
# 2846                             An Actor Prepares           6.5          10
#
# [2847 rows x 16 columns]

# %%
df_merged.columns
# Out:
# Index(['title_x', 'studio', 'domestic_gross', 'foreign_gross', 'year',
#        'clean_title', 'Unnamed: 0', 'genre_ids', 'id', 'original_language',
#        'original_title', 'popularity', 'release_date', 'title_y',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
#lets drop unnecessary columns
df_merged = df_merged.drop(columns=['Unnamed: 0', 'title_y', 'original_title', 'id', 'genre_ids'])
df_merged.head()
# Out:
#                                        title_x studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 2                                    Inception     WB     292600000.0
# 3                          Shrek Forever After   P/DW     238700000.0
# 4                   The Twilight Saga: Eclipse   Sum.     300500000.0
#
#    foreign_gross  year                                  clean_title  \
# 0    652000000.0  2010                                  toy story 3
# 1    664300000.0  2010  harry potter and the deathly hallows part 1
# 2    535700000.0  2010                                    inception
# 3    513900000.0  2010                          shrek forever after
# 4    398000000.0  2010                    the twilight saga eclipse
#
#   original_language  popularity release_date  vote_average  vote_count
# 0                en      24.445   2010-06-17           7.7        8340
# 1                en      33.533   2010-11-19           7.7       10788
# 2                en      27.920   2010-07-16           8.3       22186
# 3                en      15.041   2010-05-16           6.1        3843
# 4                en      20.340   2010-06-23           6.0        4909

# %%
#Drop null values
dfw = df_merged.dropna()
dfw
# Out:
#                                           title_x      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 2                                       Inception          WB     292600000.0
# 3                             Shrek Forever After        P/DW     238700000.0
# 4                      The Twilight Saga: Eclipse        Sum.     300500000.0
# ...                                           ...         ...             ...
# 2784                   Bilal: A New Breed of Hero          VE        491000.0
# 2787                              I Still See You         LGF          1400.0
# 2797                        The Catcher Was a Spy         IFC        725000.0
# 2809                                   Time Freak  Grindstone         10000.0
# 2810                                   Time Freak  Grindstone         10000.0
#
#       foreign_gross  year                                  clean_title  \
# 0       652000000.0  2010                                  toy story 3
# 1       664300000.0  2010  harry potter and the deathly hallows part 1
# 2       535700000.0  2010                                    inception
# 3       513900000.0  2010                          shrek forever after
# 4       398000000.0  2010                    the twilight saga eclipse
# ...             ...   ...                                          ...
# 2784      1700000.0  2018                    bilal a new breed of hero
# 2787      1500000.0  2018                              i still see you
# 2797       229000.0  2018                        the catcher was a spy
# 2809       256000.0  2018                                   time freak
# 2810       256000.0  2018                                   time freak
#
#      original_language  popularity release_date  vote_average  vote_count
# 0                   en      24.445   2010-06-17           7.7        8340
# 1                   en      33.533   2010-11-19           7.7       10788
# 2                   en      27.920   2010-07-16           8.3       22186
# 3                   en      15.041   2010-05-16           6.1        3843
# 4                   en      20.340   2010-06-23           6.0        4909
# ...                ...         ...          ...           ...         ...
# 2784                en       2.707   2018-02-02           6.8          54
# 2787                en      12.867   2018-10-12           6.8         196
# 2797                en       9.727   2018-06-22           6.2          67
# 2809                en       1.604   2011-02-10           6.9           9
# 2810                en       9.751   2018-11-09           6.3          97
#
# [1789 rows x 11 columns]

# %%
dfw1 = dfw.merge(df4, on='clean_title', how="left")
dfw1
# Out:
#                                           title_x      studio  \
# 0                                     Toy Story 3          BV
# 1     Harry Potter and the Deathly Hallows Part 1          WB
# 2                                       Inception          WB
# 3                             Shrek Forever After        P/DW
# 4                      The Twilight Saga: Eclipse        Sum.
# ...                                           ...         ...
# 1797                   Bilal: A New Breed of Hero          VE
# 1798                              I Still See You         LGF
# 1799                        The Catcher Was a Spy         IFC
# 1800                                   Time Freak  Grindstone
# 1801                                   Time Freak  Grindstone
#
#       domestic_gross_x  foreign_gross  year  \
# 0          415000000.0    652000000.0  2010
# 1          296000000.0    664300000.0  2010
# 2          292600000.0    535700000.0  2010
# 3          238700000.0    513900000.0  2010
# 4          300500000.0    398000000.0  2010
# ...                ...            ...   ...
# 1797          491000.0      1700000.0  2018
# 1798            1400.0      1500000.0  2018
# 1799          725000.0       229000.0  2018
# 1800           10000.0       256000.0  2018
# 1801           10000.0       256000.0  2018
#
#                                       clean_title original_language  \
# 0                                     toy story 3                en
# 1     harry potter and the deathly hallows part 1                en
# 2                                       inception                en
# 3                             shrek forever after                en
# 4                       the twilight saga eclipse                en
# ...                                           ...               ...
# 1797                    bilal a new breed of hero                en
# 1798                              i still see you                en
# 1799                        the catcher was a spy                en
# 1800                                   time freak                en
# 1801                                   time freak                en
#
#       popularity release_date_x  vote_average  vote_count     id  \
# 0         24.445     2010-06-17           7.7        8340   47.0
# 1         33.533     2010-11-19           7.7       10788    NaN
# 2         27.920     2010-07-16           8.3       22186   38.0
# 3         15.041     2010-05-16           6.1        3843   27.0
# 4         20.340     2010-06-23           6.0        4909   53.0
# ...          ...            ...           ...         ...    ...
# 1797       2.707     2018-02-02           6.8          54  100.0
# 1798      12.867     2018-10-12           6.8         196    NaN
# 1799       9.727     2018-06-22           6.2          67    NaN
# 1800       1.604     2011-02-10           6.9           9    NaN
# 1801       9.751     2018-11-09           6.3          97    NaN
#
#      release_date_y                       movie  production_budget  \
# 0        2010-06-18                 Toy Story 3        200000000.0
# 1               NaT                         NaN                NaN
# 2        2010-07-16                   Inception        160000000.0
# 3        2010-05-21         Shrek Forever After        165000000.0
# 4        2010-06-30  The Twilight Saga: Eclipse         68000000.0
# ...             ...                         ...                ...
# 1797     2018-02-02  Bilal: A New Breed of Hero         30000000.0
# 1798            NaT                         NaN                NaN
# 1799            NaT                         NaN                NaN
# 1800            NaT                         NaN                NaN
# 1801            NaT                         NaN                NaN
#
#       domestic_gross_y  worldwide_gross
# 0          415004880.0     1.068880e+09
# 1                  NaN              NaN
# 2          292576195.0     8.355246e+08
# 3          238736787.0     7.562447e+08
# 4          300531751.0     7.061028e+08
# ...                ...              ...
# 1797          490973.0     6.485990e+05
# 1798               NaN              NaN
# 1799               NaN              NaN
# 1800               NaN              NaN
# 1801               NaN              NaN
#
# [1802 rows x 17 columns]

# %%
# Drop unnecessary columns
dfw1 = dfw1.drop(columns=[
    'clean_title', 'id', 'release_date_y', 'movie', 'domestic_gross_x'
])

# Rename columns for clarity
dfw1 = dfw1.rename(columns={'title_x': 'title', 'release_date_x': 'release_date', 'domestic_gross_y':'domestic_gross'})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 2
#       1 # Drop unnecessary columns
# ----> 2 dfw1 = dfw1.drop(columns=[
#       3     'clean_title', 'id', 'release_date_y', 'movie', 'domestic_gross_x'
#       4 ])
#       6 # Rename columns for clarity
#       7 dfw1 = dfw1.rename(columns={'title_x': 'title', 'release_date_x': 'release_date', 'domestic_gross_y':'domestic_gross'})
#
# File ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~\anaconda3\envs\learn-env\lib\site-packages\pandas\core\indexes\base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['clean_title', 'id', 'release_date_y', 'movie', 'domestic_gross_x'] not found in axis"

# %%
dfw1
# Out:
#                                             title      studio  foreign_gross  \
# 0                                     Toy Story 3          BV    652000000.0
# 1     Harry Potter and the Deathly Hallows Part 1          WB    664300000.0
# 2                                       Inception          WB    535700000.0
# 3                             Shrek Forever After        P/DW    513900000.0
# 4                      The Twilight Saga: Eclipse        Sum.    398000000.0
# ...                                           ...         ...            ...
# 1797                   Bilal: A New Breed of Hero          VE      1700000.0
# 1798                              I Still See You         LGF      1500000.0
# 1799                        The Catcher Was a Spy         IFC       229000.0
# 1800                                   Time Freak  Grindstone       256000.0
# 1801                                   Time Freak  Grindstone       256000.0
#
#       year original_language  popularity release_date  vote_average  \
# 0     2010                en      24.445   2010-06-17           7.7
# 1     2010                en      33.533   2010-11-19           7.7
# 2     2010                en      27.920   2010-07-16           8.3
# 3     2010                en      15.041   2010-05-16           6.1
# 4     2010                en      20.340   2010-06-23           6.0
# ...    ...               ...         ...          ...           ...
# 1797  2018                en       2.707   2018-02-02           6.8
# 1798  2018                en      12.867   2018-10-12           6.8
# 1799  2018                en       9.727   2018-06-22           6.2
# 1800  2018                en       1.604   2011-02-10           6.9
# 1801  2018                en       9.751   2018-11-09           6.3
#
#       vote_count  production_budget  domestic_gross  worldwide_gross
# 0           8340        200000000.0     415004880.0     1.068880e+09
# 1          10788                NaN             NaN              NaN
# 2          22186        160000000.0     292576195.0     8.355246e+08
# 3           3843        165000000.0     238736787.0     7.562447e+08
# 4           4909         68000000.0     300531751.0     7.061028e+08
# ...          ...                ...             ...              ...
# 1797          54         30000000.0        490973.0     6.485990e+05
# 1798         196                NaN             NaN              NaN
# 1799          67                NaN             NaN              NaN
# 1800           9                NaN             NaN              NaN
# 1801          97                NaN             NaN              NaN
#
# [1802 rows x 12 columns]

# %%
dfg = dfw1.dropna()
dfg
# Out:
#                            title       studio  foreign_gross  year  \
# 0                    Toy Story 3           BV    652000000.0  2010
# 2                      Inception           WB    535700000.0  2010
# 3            Shrek Forever After         P/DW    513900000.0  2010
# 4     The Twilight Saga: Eclipse         Sum.    398000000.0  2010
# 5                     Iron Man 2         Par.    311500000.0  2010
# ...                          ...          ...            ...   ...
# 1774               Hotel Artemis  Global Road      6000000.0  2018
# 1779                         Kin          LGF      4300000.0  2018
# 1783                    Suspiria       Amazon      5400000.0  2018
# 1787                   Destroyer    Annapurna      4000000.0  2018
# 1797  Bilal: A New Breed of Hero           VE      1700000.0  2018
#
#      original_language  popularity release_date  vote_average  vote_count  \
# 0                   en      24.445   2010-06-17           7.7        8340
# 2                   en      27.920   2010-07-16           8.3       22186
# 3                   en      15.041   2010-05-16           6.1        3843
# 4                   en      20.340   2010-06-23           6.0        4909
# 5                   en      28.515   2010-05-07           6.8       12368
# ...                ...         ...          ...           ...         ...
# 1774                en      14.585   2018-06-08           5.9         471
# 1779                en      23.805   2018-08-31           6.2         289
# 1783                en      16.925   2018-10-26           7.0         752
# 1787                en      17.815   2018-12-25           5.9         176
# 1797                en       2.707   2018-02-02           6.8          54
#
#       production_budget  domestic_gross  worldwide_gross
# 0           200000000.0     415004880.0     1.068880e+09
# 2           160000000.0     292576195.0     8.355246e+08
# 3           165000000.0     238736787.0     7.562447e+08
# 4            68000000.0     300531751.0     7.061028e+08
# 5           170000000.0     312433331.0     6.211564e+08
# ...                 ...             ...              ...
# 1774         15000000.0       6708137.0     1.275880e+07
# 1779         30000000.0       5718096.0     1.009682e+07
# 1783         20000000.0       2483472.0     7.034615e+06
# 1787          9000000.0       1533324.0     3.681096e+06
# 1797         30000000.0        490973.0     6.485990e+05
#
# [1300 rows x 12 columns]

# %%
def clean_studio(name):
    if pd.isnull(name):
        return ""
    name = name.lower().strip()
    name = re.sub(r'\s+', ' ', name)          # Normalize multiple spaces
    name = re.sub(r'[^a-z0-9& ]', '', name)   # Remove punctuation except "&"
    return name

# %%
dfg.loc[:, 'clean_studio'] = dfg['studio'].apply(clean_studio)
df1.loc[:, 'clean_studio'] = df1['studio'].apply(clean_studio)
# Out:
# C:\Users\Chris\AppData\Local\Temp\ipykernel_6920\1243945274.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfg.loc[:, 'clean_studio'] = dfg['studio'].apply(clean_studio)

# %%
df1 = df1.dropna()

# %%
merged_df = dfg.merge(df1, on='clean_studio', how='inner')
merged_df
# Out:
#                    title studio_x  foreign_gross  year original_language  \
# 0              Inception       WB    535700000.0  2010                en
# 1               Due Date       WB    111200000.0  2010                en
# 2              Yogi Bear       WB    101300000.0  2010                en
# 3        The Book of Eli       WB     62300000.0  2010                en
# 4               The Town       WB     61800000.0  2010                en
# ..                   ...      ...            ...   ...               ...
# 148            Lady Bird      A24     30000000.0  2017                en
# 149  The Disaster Artist      A24      8700000.0  2017                en
# 150  The Disaster Artist      A24      8700000.0  2017                en
# 151    It Comes At Night      A24      5300000.0  2017                en
# 152           Hereditary      A24     35300000.0  2018                en
#
#      popularity release_date  vote_average  vote_count  production_budget  \
# 0        27.920   2010-07-16           8.3       22186        160000000.0
# 1        12.445   2010-11-04           6.3        2973         65000000.0
# 2         9.096   2010-12-17           5.3         387         80000000.0
# 3        18.985   2010-01-11           6.7        3495         80000000.0
# 4        13.476   2010-09-17           7.1        2386         37000000.0
# ..          ...          ...           ...         ...                ...
# 148      15.974   2017-11-03           7.3        3866         10000000.0
# 149      13.270   2017-12-01           7.2        1895         10000000.0
# 150      13.270   2017-12-01           7.2        1895         10000000.0
# 151      12.337   2017-06-09           5.8        1141          5000000.0
# 152      26.185   2018-06-08           7.0        2491         10000000.0
#
#      ...  rating                       genre            director  \
# 0    ...       R  Drama|Mystery and Suspense      Clint Eastwood
# 1    ...       R  Drama|Mystery and Suspense      Clint Eastwood
# 2    ...       R  Drama|Mystery and Suspense      Clint Eastwood
# 3    ...       R  Drama|Mystery and Suspense      Clint Eastwood
# 4    ...       R  Drama|Mystery and Suspense      Clint Eastwood
# ..   ...     ...                         ...                 ...
# 148  ...       R                Drama|Horror  Trey Edward Shults
# 149  ...       R                Drama|Horror  Trey Edward Shults
# 150  ...       R                Drama|Horror  Trey Edward Shults
# 151  ...       R                Drama|Horror  Trey Edward Shults
# 152  ...       R                Drama|Horror  Trey Edward Shults
#
#                  writer theater_date   dvd_date currency  box_office  \
# 0       Brian Helgeland   2003-10-08 2004-06-08        $  88,800,000
# 1       Brian Helgeland   2003-10-08 2004-06-08        $  88,800,000
# 2       Brian Helgeland   2003-10-08 2004-06-08        $  88,800,000
# 3       Brian Helgeland   2003-10-08 2004-06-08        $  88,800,000
# 4       Brian Helgeland   2003-10-08 2004-06-08        $  88,800,000
# ..                  ...          ...        ...      ...         ...
# 148  Trey Edward Shults   2017-06-09 2017-09-12        $  13,985,117
# 149  Trey Edward Shults   2017-06-09 2017-09-12        $  13,985,117
# 150  Trey Edward Shults   2017-06-09 2017-09-12        $  13,985,117
# 151  Trey Edward Shults   2017-06-09 2017-09-12        $  13,985,117
# 152  Trey Edward Shults   2017-06-09 2017-09-12        $  13,985,117
#
#          runtime studio_y
# 0    137 minutes       WB
# 1    137 minutes       WB
# 2    137 minutes       WB
# 3    137 minutes       WB
# 4    137 minutes       WB
# ..           ...      ...
# 148   91 minutes      A24
# 149   91 minutes      A24
# 150   91 minutes      A24
# 151   91 minutes      A24
# 152   91 minutes      A24
#
# [153 rows x 25 columns]

# %%
merged_df['genre'].unique()
# Out:
# array(['Drama|Mystery and Suspense',
#        'Art House and International|Comedy|Drama|Musical and Performing Arts',
#        'Drama|Horror|Mystery and Suspense', 'Drama',
#        'Action and Adventure|Mystery and Suspense', 'Drama|Horror'],
#       dtype=object)

# %%
merged_df.columns
# Out:
# Index(['title', 'studio_x', 'foreign_gross', 'year', 'original_language',
#        'popularity', 'release_date', 'vote_average', 'vote_count',
#        'production_budget', 'domestic_gross', 'worldwide_gross',
#        'clean_studio', 'id', 'synopsis', 'rating', 'genre', 'director',
#        'writer', 'theater_date', 'dvd_date', 'currency', 'box_office',
#        'runtime', 'studio_y'],
#       dtype='object')

# %%
# Drop unnecessary columns
merged_df = merged_df.drop(columns=[
    'studio_y', 'clean_studio', 'id', 'synopsis', 'dvd_date', 'theater_date', 'currency', 'box_office'
])

# Optionally rename studio_x to just 'studio'
merged_df = merged_df.rename(columns={'studio_x': 'studio'})
merged_df
# Out:
#                              title studio  foreign_gross  year  \
# 0                        Inception     WB    535700000.0  2010
# 1                         Due Date     WB    111200000.0  2010
# 2                        Yogi Bear     WB    101300000.0  2010
# 3                  The Book of Eli     WB     62300000.0  2010
# 4                         The Town     WB     61800000.0  2010
# ..                             ...    ...            ...   ...
# 148                       The Mule     WB     68700000.0  2018
# 149                     Hereditary    A24     35300000.0  2018
# 150                      12 Strong     WB     21600000.0  2018
# 151             The 15:17 to Paris     WB     20800000.0  2018
# 152  Teen Titans Go! To The Movies     WB     22300000.0  2018
#
#     original_language  popularity release_date  vote_average  vote_count  \
# 0                  en      27.920   2010-07-16           8.3       22186
# 1                  en      12.445   2010-11-04           6.3        2973
# 2                  en       9.096   2010-12-17           5.3         387
# 3                  en      18.985   2010-01-11           6.7        3495
# 4                  en      13.476   2010-09-17           7.1        2386
# ..                ...         ...          ...           ...         ...
# 148                en      33.830   2018-12-14           6.5        1584
# 149                en      26.185   2018-06-08           7.0        2491
# 150                en      13.183   2018-01-19           5.6        1312
# 151                en      11.576   2018-02-09           5.3         799
# 152                en      16.523   2018-07-27           7.0         304
#
#      production_budget  domestic_gross  worldwide_gross rating  \
# 0          160000000.0     292576195.0      835524642.0      R
# 1           65000000.0     100539043.0      211739043.0      R
# 2           80000000.0     100246011.0      204774690.0      R
# 3           80000000.0      94835059.0      158750817.0      R
# 4           37000000.0      92186262.0      152566881.0      R
# ..                 ...             ...              ...    ...
# 148         50000000.0     103804407.0      170857676.0      R
# 149         10000000.0      44069456.0       70133905.0      R
# 150         35000000.0      45819713.0       71118378.0      R
# 151         30000000.0      36276286.0       56096200.0      R
# 152         10000000.0      29790236.0       51620593.0      R
#
#                           genre            director              writer  \
# 0    Drama|Mystery and Suspense      Clint Eastwood     Brian Helgeland
# 1    Drama|Mystery and Suspense      Clint Eastwood     Brian Helgeland
# 2    Drama|Mystery and Suspense      Clint Eastwood     Brian Helgeland
# 3    Drama|Mystery and Suspense      Clint Eastwood     Brian Helgeland
# 4    Drama|Mystery and Suspense      Clint Eastwood     Brian Helgeland
# ..                          ...                 ...                 ...
# 148  Drama|Mystery and Suspense      Clint Eastwood     Brian Helgeland
# 149                Drama|Horror  Trey Edward Shults  Trey Edward Shults
# 150  Drama|Mystery and Suspense      Clint Eastwood     Brian Helgeland
# 151  Drama|Mystery and Suspense      Clint Eastwood     Brian Helgeland
# 152  Drama|Mystery and Suspense      Clint Eastwood     Brian Helgeland
#
#          runtime
# 0    137 minutes
# 1    137 minutes
# 2    137 minutes
# 3    137 minutes
# 4    137 minutes
# ..           ...
# 148  137 minutes
# 149   91 minutes
# 150  137 minutes
# 151  137 minutes
# 152  137 minutes
#
# [153 rows x 17 columns]

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              153 non-null    object
#  1   studio_x           153 non-null    object
#  2   foreign_gross      153 non-null    float64
#  3   year               153 non-null    int64
#  4   original_language  153 non-null    object
#  5   popularity         153 non-null    float64
#  6   release_date       153 non-null    object
#  7   vote_average       153 non-null    float64
#  8   vote_count         153 non-null    int64
#  9   production_budget  153 non-null    float64
#  10  domestic_gross     153 non-null    float64
#  11  worldwide_gross    153 non-null    float64
#  12  clean_studio       153 non-null    object
#  13  id                 153 non-null    int64
#  14  synopsis           153 non-null    object
#  15  rating             153 non-null    object
#  16  genre              153 non-null    object
#  17  director           153 non-null    object
#  18  writer             153 non-null    object
#  19  theater_date       153 non-null    datetime64[ns]
#  20  dvd_date           153 non-null    datetime64[ns]
#  21  currency           153 non-null    object
#  22  box_office         153 non-null    object
#  23  runtime            153 non-null    object
#  24  studio_y           153 non-null    object
# dtypes: datetime64[ns](2), float64(6), int64(3), object(14)
# memory usage: 30.0+ KB

# %% [markdown]
# ## Finding the net revenue of the movies

# %%
merged_df['net_revenue'] = merged_df['domestic_gross'] + merged_df['worldwide_gross'] - merged_df['production_budget']
merged_df[['title','genre','net_revenue']]
# Out:
#                    title                       genre  net_revenue
# 0              Inception  Drama|Mystery and Suspense  968100837.0
# 1               Due Date  Drama|Mystery and Suspense  247278086.0
# 2              Yogi Bear  Drama|Mystery and Suspense  225020701.0
# 3        The Book of Eli  Drama|Mystery and Suspense  173585876.0
# 4               The Town  Drama|Mystery and Suspense  207753143.0
# ..                   ...                         ...          ...
# 148            Lady Bird                Drama|Horror  117569042.0
# 149  The Disaster Artist                Drama|Horror   39838283.0
# 150  The Disaster Artist                Drama|Horror   39838283.0
# 151    It Comes At Night                Drama|Horror   28705320.0
# 152           Hereditary                Drama|Horror  104203361.0
#
# [153 rows x 3 columns]

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   title              153 non-null    object
#  1   studio_x           153 non-null    object
#  2   foreign_gross      153 non-null    float64
#  3   year               153 non-null    int64
#  4   original_language  153 non-null    object
#  5   popularity         153 non-null    float64
#  6   release_date       153 non-null    object
#  7   vote_average       153 non-null    float64
#  8   vote_count         153 non-null    int64
#  9   production_budget  153 non-null    float64
#  10  domestic_gross     153 non-null    float64
#  11  worldwide_gross    153 non-null    float64
#  12  clean_studio       153 non-null    object
#  13  id                 153 non-null    int64
#  14  synopsis           153 non-null    object
#  15  rating             153 non-null    object
#  16  genre              153 non-null    object
#  17  director           153 non-null    object
#  18  writer             153 non-null    object
#  19  theater_date       153 non-null    datetime64[ns]
#  20  dvd_date           153 non-null    datetime64[ns]
#  21  currency           153 non-null    object
#  22  box_office         153 non-null    object
#  23  runtime            153 non-null    object
#  24  studio_y           153 non-null    object
#  25  net_revenue        153 non-null    float64
# dtypes: datetime64[ns](2), float64(7), int64(3), object(14)
# memory usage: 31.2+ KB

# %% [markdown]
# ## Ratings across the movie genres

# %%
#Drama|Horror and Drama|Mystery|Suspense are the top genres
merged_df[['genre','vote_average','title']].groupby(by ='genre').describe()
# Out:
#                                                    vote_average            \
#                                                           count      mean
# genre
# Action and Adventure|Mystery and Suspense                   2.0  6.350000
# Art House and International|Comedy|Drama|Musica...          2.0  6.350000
# Drama                                                       2.0  6.350000
# Drama|Horror                                               18.0  6.761111
# Drama|Horror|Mystery and Suspense                           2.0  6.350000
# Drama|Mystery and Suspense                                127.0  6.491339
#
#                                                                           \
#                                                          std  min    25%
# genre
# Action and Adventure|Mystery and Suspense           0.494975  6.0  6.175
# Art House and International|Comedy|Drama|Musica...  0.494975  6.0  6.175
# Drama                                               0.494975  6.0  6.175
# Drama|Horror                                        0.813228  5.0  6.300
# Drama|Horror|Mystery and Suspense                   0.494975  6.0  6.175
# Drama|Mystery and Suspense                          0.758656  4.3  6.000
#
#
#                                                      50%    75%   max
# genre
# Action and Adventure|Mystery and Suspense           6.35  6.525   6.7
# Art House and International|Comedy|Drama|Musica...  6.35  6.525   6.7
# Drama                                               6.35  6.525   6.7
# Drama|Horror                                        6.65  7.275   8.1
# Drama|Horror|Mystery and Suspense                   6.35  6.525   6.7
# Drama|Mystery and Suspense                          6.40  6.950  10.0

# %% [markdown]
# ## Ratings of the movies from the directors

# %%
# Trey Edward Shults and Clint Eastwood are the top directors
merged_df[['genre','vote_average','director']].groupby(by ='director').describe()
# Out:
#                     vote_average                                               \
#                            count      mean       std  min    25%   50%    75%
# director
# Bryan Singer                 2.0  6.350000  0.494975  6.0  6.175  6.35  6.525
# Clint Eastwood             125.0  6.493600  0.763243  4.3  6.000  6.40  7.000
# George Hickenlooper          2.0  6.350000  0.494975  6.0  6.175  6.35  6.525
# Jim Jarmusch                 2.0  6.350000  0.494975  6.0  6.175  6.35  6.525
# Peter Webber                 2.0  6.350000  0.494975  6.0  6.175  6.35  6.525
# Sam Mendes                   2.0  6.350000  0.494975  6.0  6.175  6.35  6.525
# Trey Edward Shults          18.0  6.761111  0.813228  5.0  6.300  6.65  7.275
#
#
#                       max
# director
# Bryan Singer          6.7
# Clint Eastwood       10.0
# George Hickenlooper   6.7
# Jim Jarmusch          6.7
# Peter Webber          6.7
# Sam Mendes            6.7
# Trey Edward Shults    8.1

# %% [markdown]
# ## Net revenue generated across the genres

# %%
# Drama|Horror genre generated the highest revenue
merged_df[['genre','net_revenue']].groupby(by ='genre').describe()
# Out:
#                                                    net_revenue                \
#                                                          count          mean
# genre
# Action and Adventure|Mystery and Suspense                  2.0  1.797725e+08
# Art House and International|Comedy|Drama|Musica...         2.0  1.797725e+08
# Drama                                                      2.0  1.797725e+08
# Drama|Horror                                              18.0  4.187732e+07
# Drama|Horror|Mystery and Suspense                          2.0  1.797725e+08
# Drama|Mystery and Suspense                               127.0  2.400106e+08
#
#                                                                               \
#                                                              std         min
# genre
# Action and Adventure|Mystery and Suspense           1.407636e+08  80237609.0
# Art House and International|Comedy|Drama|Musica...  1.407636e+08  80237609.0
# Drama                                               1.407636e+08  80237609.0
# Drama|Horror                                        3.930175e+07  -5403991.0
# Drama|Horror|Mystery and Suspense                   1.407636e+08  80237609.0
# Drama|Mystery and Suspense                          2.977810e+08 -32847013.0
#
#                                                                               \
#                                                             25%          50%
# genre
# Action and Adventure|Mystery and Suspense           130005059.5  179772510.0
# Art House and International|Comedy|Drama|Musica...  130005059.5  179772510.0
# Drama                                               130005059.5  179772510.0
# Drama|Horror                                         15085893.0   38889370.0
# Drama|Horror|Mystery and Suspense                   130005059.5  179772510.0
# Drama|Mystery and Suspense                           55687033.0  128404604.0
#
#
#                                                             75%           max
# genre
# Action and Adventure|Mystery and Suspense           229539960.5  2.793074e+08
# Art House and International|Comedy|Drama|Musica...  229539960.5  2.793074e+08
# Drama                                               229539960.5  2.793074e+08
# Drama|Horror                                         59269759.5  1.175690e+08
# Drama|Horror|Mystery and Suspense                   229539960.5  2.793074e+08
# Drama|Mystery and Suspense                          286027461.5  1.321956e+09

# %% [markdown]
# ## Ratings of  movies from the writers

# %%
# Trey Edward Shults and Brian Helgeland are the top writers with average movie ratiing of 6.76 and 6.49
merged_df[['genre','vote_average','writer']].groupby(by ='writer').describe()
# Out:
#                                        vote_average                           \
#                                               count      mean       std  min
# writer
# Brian Helgeland                               125.0  6.493600  0.763243  4.3
# Captain Mauzner                                 2.0  6.350000  0.494975  6.0
# Christopher McQuarrie|Nathan Alexander          2.0  6.350000  0.494975  6.0
# Jim Jarmusch                                    2.0  6.350000  0.494975  6.0
# John Logan|Robert Wade|Neal Purvis              2.0  6.350000  0.494975  6.0
# Thomas Harris                                   2.0  6.350000  0.494975  6.0
# Trey Edward Shults                             18.0  6.761111  0.813228  5.0
#
#
#                                           25%   50%    75%   max
# writer
# Brian Helgeland                         6.000  6.40  7.000  10.0
# Captain Mauzner                         6.175  6.35  6.525   6.7
# Christopher McQuarrie|Nathan Alexander  6.175  6.35  6.525   6.7
# Jim Jarmusch                            6.175  6.35  6.525   6.7
# John Logan|Robert Wade|Neal Purvis      6.175  6.35  6.525   6.7
# Thomas Harris                           6.175  6.35  6.525   6.7
# Trey Edward Shults                      6.300  6.65  7.275   8.1

# %% [markdown]
# ## Distribution of the genres across the years

# %%
sns.scatterplot(data=merged_df,x='year',y='genre')
# Out:
# <Axes: xlabel='year', ylabel='genre'>

# %% [markdown]
# ## Overall ratings of the movie genres

# %%
a = merged_df['vote_average']
b = merged_df['genre']
plt.scatter(a,b)
plt.show()

# %% [markdown]
# ## Directors and the ratings of their movies

# %%
a = merged_df['vote_average']
b = merged_df['director']
plt.scatter(a,b)
plt.show()

# %% [markdown]
# ## Writers and the movie ratings

# %%
a = merged_df['vote_average']
b = merged_df['writer']
plt.scatter(a,b)
plt.show()

# %% [markdown]
# ## Net Revenue across the movie genres

# %%
sns.scatterplot(data=merged_df,x='net_revenue',y='genre')
# Out:
# <Axes: xlabel='net_revenue', ylabel='genre'>

# %% [markdown]
# # Conclusion
# #### Drama|Horror and Drama|Mystery|Suspense are suitable genres for the studio due to the high ratings.
# #### Trey Edward Shults and Clint Eastwood are possible directors to work with the studio.
# ####  Trey Edward SHults and Brian Helgeland should be hired into the studio as writers.
# #### Drama|Horror genre generates the most revenue.
